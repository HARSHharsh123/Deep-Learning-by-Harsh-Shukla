# %%
from sklearn.datasets import make_classification

# %%
X , y = make_classification(n_samples = 100 , n_features = 2 , n_informative = 1 , n_redundant= 0, n_classes = 2, n_clusters_per_class= 1 , hypercube= False , random_state=41, class_sep=15 )

# %%
import matplotlib.pyplot as plt
plt.scatter(x = X[:,0] , y = X[:,1] , c = y, cmap = 'winter')

# %%
X.shape , y.shape
# Out:
# ((100, 2), (100,))

# %%
def Perceptron_Loss(X , y):
    w1 = w2 = b = 1
    lr = 0.1
    for j in range(1000):
        for i in range(X.shape[0]): ## we are running our loop for 100 data values / points 
            ## finding f(xi) or z 
            z = w1 * X[i][0] + w2 * X[i][1] + b
            ## checking condition 
            if z * y[i] < 0: ## and after updating values of w1 , w2 , b 
                w1 = w1 + lr * y[i] * X[i][0]
                w2 = w2 + lr * y[i] * X[i][1]
                b = b + lr * y[i]
    return w1 , w2 , b

# %%
w1 , w2 , b = Perceptron_Loss(X,y)

# %%
w1
# Out:
# 1.006638570722407

# %%
w2
# Out:
# 0.22215119727529098

# %%
b
# Out:
# 1.3000000000000003

# %%
m = -(w1 / w2)
c = -(b / w2)

# %%
m
# Out:
# -4.531321834268464

# %%
c
# Out:
# -5.851870329508209

# %%
import numpy as np
x_input = np.linspace(-3,3 , 100)
y_input = m * x_input + c

# %%
plt.plot(x_input , y_input , c = 'red')
plt.scatter(x = X[:,0] , y = X[:,1] , c = y, cmap = 'winter')
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_or = pd.DataFrame()
df_and = pd.DataFrame()
df_xor = pd.DataFrame()

# %%
df_or['input1'] = [1,1,0,0]
df_or['input2'] = [1,0,1,0]
df_or['output'] = [1,1,1,0]

# %%
df_and['input1'] = [1,1,0,0]
df_and['input2'] = [1,0,1,0]
df_and['output'] = [1,0,0,0]

# %%
df_xor['input1'] = [1,1,0,0]
df_xor['input2'] = [1,0,1,0]
df_xor['output'] = [0,1,1,0]

# %%
plt.scatter(df_or.iloc[:,0] , df_or.iloc[:,1] , c = df_or['output'] , s = 200 , cmap = 'winter')

# %%
plt.scatter(df_and.iloc[:,0] , df_and.iloc[:,1] , c = df_and['output'] , s = 200 , cmap = 'winter')

# %%
plt.scatter(df_xor.iloc[:,0] , df_xor.iloc[:,1] , c = df_xor['output'] , s = 200 , cmap = 'winter')

# %%
from sklearn.linear_model import Perceptron
p_or = Perceptron()

# %%
p_and = Perceptron()

# %%
p_xor = Perceptron()

# %%
p_or.fit(df_or.iloc[:,:-1].values, df_or.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
p_and.fit(df_and.iloc[:,:-1].values, df_and.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
p_xor.fit(df_xor.iloc[:,:-1].values, df_xor.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(df_or.iloc[:,:-1].values , df_or.iloc[:,-1].values, clf = p_or)
# Out:
# <AxesSubplot:>

# %%
plot_decision_regions(df_and.iloc[:,:-1].values , df_and.iloc[:,-1].values, clf = p_and)
# Out:
# <AxesSubplot:>

# %%
plot_decision_regions(df_xor.iloc[:,:-1].values , df_xor.iloc[:,-1].values, clf = p_xor)
# Out:
# C:\Users\hs081\AppData\Roaming\Python\Python39\site-packages\mlxtend\plotting\decision_regions.py:315: UserWarning: No contour levels were found within the data range.
#   ax.contour(xx, yy, Z, cset.levels, **contour_kwargs)
# <AxesSubplot:>

# %%
def Perceptron(X , y):
    w1 = w2 = b = 1
    lr = 0.1
    for j in range(10000):
        for i in range(X.shape[0]): ## we are running our loop for 100 data values / points 
            ## finding f(xi) or z 
            z = w1 * X[i][0] + w2 * X[i][1] + b
            ## checking condition 
            if z * y[i] < 0: ## and after updating values of w1 , w2 , b 
                w1 = w1 + lr * y[i] * X[i][0]
                w2 = w2 + lr * y[i] * X[i][1]
                b = b + lr * y[i]
    return w1 , w2 , b

# %%
df_or.iloc[:,:-1].values
# Out:
# array([[1, 1],
#        [1, 0],
#        [0, 1],
#        [0, 0]], dtype=int64)

# %%
df_or.iloc[:,-1].values
# Out:
# array([1, 1, 1, 0], dtype=int64)

# %%
w1 , w2 , b = Perceptron(df_xor.iloc[:,:-1].values , df_xor.iloc[:,-1].values)

# %%
w1
# Out:
# 1

# %%
w2
# Out:
# 1

# %%
b
# Out:
# 1

# %%
m = -(w1 / w2)
c = -(b / w2)

# %%
m
# Out:
# -1.0

# %%
c
# Out:
# -1.0

# %%
x_input = np.linspace(-1,1,5)
y_input = -x_input + 1

# %%
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(df_xor.iloc[:,0] , df_xor.iloc[:,1] , c = df_xor['output'] , s = 200 , cmap = 'winter')
plt.ylim(-1,2)
# Out:
# (-1.0, 2.0)
